# %% [markdown]
# # House Price Prediction - Advanced Regression Techniques
# Dataset Link - https://www.kaggle.com/c/house-prices-advanced-regression-techniques
# ## Feature Engineering

# %% [markdown]
# To avoid data leakage we apply feature engineering to train data and test data separately, although we follow the same exact steps as done in train data. Also, we directly use any learned parameters from the train data into the test data, for example, standard/minmax scalers or mean/standard deviation values, etc. <br> <br>
# We first applying feature engineering techniques on the train data and then we will follow up on the test data as well.

# %% [markdown]
# ### Train Data

# %% [markdown]
# #### Importing required libraries and the training dataset

# %%
# Importing necessary libraries
import pickle
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# %matplotlib inline
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Reading the dataset
df = pd.read_csv('train.csv', index_col='Id')
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2          Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 3          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 4          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 5          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1        Norm     1Fam     2Story            7            5       2003
# 2        Norm     1Fam     1Story            6            8       1976
# 3        Norm     1Fam     2Story            7            5       2001
# 4        Norm     1Fam     2Story            7            5       1915
# 5        Norm     1Fam     2Story            8            5       2000
#
#     YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1           2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 2           1976     Gable  CompShg     MetalSd     MetalSd       None
# 3           2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 4           1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 5           2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#     MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# Id
# 1        196.0        Gd        TA      PConc       Gd       TA           No
# 2          0.0        TA        TA     CBlock       Gd       TA           Gd
# 3        162.0        Gd        TA      PConc       Gd       TA           Mn
# 4          0.0        TA        TA     BrkTil       TA       Gd           No
# 5        350.0        Gd        TA      PConc       Gd       TA           Av
#
#    BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# Id
# 1           GLQ         706          Unf           0        150          856
# 2           ALQ         978          Unf           0        284         1262
# 3           GLQ         486          Unf           0        434          920
# 4           ALQ         216          Unf           0        540          756
# 5           GLQ         655          Unf           0        490         1145
#
#    Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# Id
# 1     GasA        Ex          Y      SBrkr       856       854             0
# 2     GasA        Ex          Y      SBrkr      1262         0             0
# 3     GasA        Ex          Y      SBrkr       920       866             0
# 4     GasA        Gd          Y      SBrkr       961       756             0
# 5     GasA        Ex          Y      SBrkr      1145      1053             0
#
#     GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# Id
# 1        1710             1             0         2         1             3
# 2        1262             0             1         2         0             3
# 3        1786             1             0         2         1             3
# 4        1717             1             0         1         0             3
# 5        2198             1             0         2         1             4
#
#     KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# Id
# 1              1          Gd             8        Typ           0         NaN
# 2              1          TA             6        Typ           1          TA
# 3              1          Gd             6        Typ           1          TA
# 4              1          Gd             7        Typ           1          Gd
# 5              1          Gd             9        Typ           1          TA
#
#    GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# Id
# 1      Attchd       2003.0          RFn           2         548         TA
# 2      Attchd       1976.0          RFn           2         460         TA
# 3      Attchd       2001.0          RFn           2         608         TA
# 4      Detchd       1998.0          Unf           3         642         TA
# 5      Attchd       2000.0          RFn           3         836         TA
#
#    GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 1          TA          Y           0           61              0          0
# 2          TA          Y         298            0              0          0
# 3          TA          Y           0           42              0          0
# 4          TA          Y           0           35            272          0
# 5          TA          Y         192           84              0          0
#
#     ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# Id
# 1             0         0    NaN   NaN         NaN        0       2    2008
# 2             0         0    NaN   NaN         NaN        0       5    2007
# 3             0         0    NaN   NaN         NaN        0       9    2008
# 4             0         0    NaN   NaN         NaN        0       2    2006
# 5             0         0    NaN   NaN         NaN        0      12    2008
#
#    SaleType SaleCondition  SalePrice
# Id
# 1        WD        Normal     208500
# 2        WD        Normal     181500
# 3        WD        Normal     223500
# 4        WD       Abnorml     140000
# 5        WD        Normal     250000

# %%
# Printing shape of training dataset
df.shape
# Out:
# (1460, 80)

# %% [markdown]
# #### Handling Missing/NaN Values in Numerical Features

# %%
# Calculating percentage of NaN values (in columns with NaN values present) in numerical features
features_with_nan = [feature for feature in df.columns if df[feature].isnull().sum() > 0 and df[feature].dtype != 'O']

for feature in features_with_nan:
    print(feature, ':', round(df[feature].isnull().mean() * 100, 2), '%')
# Out:
# LotFrontage : 17.74 %
# MasVnrArea : 0.55 %
# GarageYrBlt : 5.55 %

# %% [markdown]
# - We saw in exploratory data analysis that numerical features had a lot of ouliers. In those cases we should replace NaN values with median or mode only and not the mean, as median/mode are less sensitive to outliers.
# - Here we would replace the NaN values with the median value of that feature
# - Also, it is better to capture the presence of a NaN value in a separate/new feature
# - We will capture NaN values in new feature for 'LotFrontage' and 'GarageYrBlt' only, as in the test data even more features have missing/NaN values, thus the dimensions of the dataframes will become different. 'LotFrontage' and 'GarageYrBlt' have high number of NaN values in both trainand test data, so we would create new features for them only.

# %%
# Replacing NaN values with the median of that feature
for feature in features_with_nan:
    if feature == 'LotFrontage' or feature == 'GarageYrBlt':
        df[feature+'_NaN'] = np.where(df[feature].isnull(), 1, 0)
    df[feature] = df[feature].fillna(df[feature].median())
    
# Printing number of NaN values in numerical features after handling them
df[features_with_nan].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %% [markdown]
# - Value 1 in ' feature_name+"_nan" ' represents a NaN value present while 0 represents NaN value absent for that row
# - Zero values in the output denote that all the NaN values have been replaced by the median and no NaN values are present now

# %%
# Printing updated dataframe
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2          Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 3          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 4          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 5          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1        Norm     1Fam     2Story            7            5       2003
# 2        Norm     1Fam     1Story            6            8       1976
# 3        Norm     1Fam     2Story            7            5       2001
# 4        Norm     1Fam     2Story            7            5       1915
# 5        Norm     1Fam     2Story            8            5       2000
#
#     YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1           2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 2           1976     Gable  CompShg     MetalSd     MetalSd       None
# 3           2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 4           1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 5           2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#     MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# Id
# 1        196.0        Gd        TA      PConc       Gd       TA           No
# 2          0.0        TA        TA     CBlock       Gd       TA           Gd
# 3        162.0        Gd        TA      PConc       Gd       TA           Mn
# 4          0.0        TA        TA     BrkTil       TA       Gd           No
# 5        350.0        Gd        TA      PConc       Gd       TA           Av
#
#    BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# Id
# 1           GLQ         706          Unf           0        150          856
# 2           ALQ         978          Unf           0        284         1262
# 3           GLQ         486          Unf           0        434          920
# 4           ALQ         216          Unf           0        540          756
# 5           GLQ         655          Unf           0        490         1145
#
#    Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# Id
# 1     GasA        Ex          Y      SBrkr       856       854             0
# 2     GasA        Ex          Y      SBrkr      1262         0             0
# 3     GasA        Ex          Y      SBrkr       920       866             0
# 4     GasA        Gd          Y      SBrkr       961       756             0
# 5     GasA        Ex          Y      SBrkr      1145      1053             0
#
#     GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# Id
# 1        1710             1             0         2         1             3
# 2        1262             0             1         2         0             3
# 3        1786             1             0         2         1             3
# 4        1717             1             0         1         0             3
# 5        2198             1             0         2         1             4
#
#     KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# Id
# 1              1          Gd             8        Typ           0         NaN
# 2              1          TA             6        Typ           1          TA
# 3              1          Gd             6        Typ           1          TA
# 4              1          Gd             7        Typ           1          Gd
# 5              1          Gd             9        Typ           1          TA
#
#    GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# Id
# 1      Attchd       2003.0          RFn           2         548         TA
# 2      Attchd       1976.0          RFn           2         460         TA
# 3      Attchd       2001.0          RFn           2         608         TA
# 4      Detchd       1998.0          Unf           3         642         TA
# 5      Attchd       2000.0          RFn           3         836         TA
#
#    GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 1          TA          Y           0           61              0          0
# 2          TA          Y         298            0              0          0
# 3          TA          Y           0           42              0          0
# 4          TA          Y           0           35            272          0
# 5          TA          Y         192           84              0          0
#
#     ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# Id
# 1             0         0    NaN   NaN         NaN        0       2    2008
# 2             0         0    NaN   NaN         NaN        0       5    2007
# 3             0         0    NaN   NaN         NaN        0       9    2008
# 4             0         0    NaN   NaN         NaN        0       2    2006
# 5             0         0    NaN   NaN         NaN        0      12    2008
#
#    SaleType SaleCondition  SalePrice  LotFrontage_NaN  GarageYrBlt_NaN
# Id
# 1        WD        Normal     208500                0                0
# 2        WD        Normal     181500                0                0
# 3        WD        Normal     223500                0                0
# 4        WD       Abnorml     140000                0                0
# 5        WD        Normal     250000                0                0

# %% [markdown]
# #### Handling Missing/NaN Values in Categorical Features

# %%
# Calculating percentage of NaN values (in columns with NaN values present) in categorical features
features_with_nan = [feature for feature in df.columns if df[feature].isnull().sum() > 0 and df[feature].dtype == 'O']

for feature in features_with_nan:
    print(feature, ':', round(df[feature].isnull().mean() * 100, 2), '%')
# Out:
# Alley : 93.77 %
# MasVnrType : 0.55 %
# BsmtQual : 2.53 %
# BsmtCond : 2.53 %
# BsmtExposure : 2.6 %
# BsmtFinType1 : 2.53 %
# BsmtFinType2 : 2.6 %
# Electrical : 0.07 %
# FireplaceQu : 47.26 %
# GarageType : 5.55 %
# GarageFinish : 5.55 %
# GarageQual : 5.55 %
# GarageCond : 5.55 %
# PoolQC : 99.52 %
# Fence : 80.75 %
# MiscFeature : 96.3 %

# %%
# Replacing NaN values with a new label called 'Missing'
df[features_with_nan] = df[features_with_nan].fillna('Missing')
df[features_with_nan].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# Electrical      0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %% [markdown]
# - Zero values in the output denote that all the NaN values have been replaced by the label 'Missing' and no NaN values are present now
# - All NaN values are replaced by a new category called 'Missing'

# %%
# Printing updated dataframe
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave  Missing      Reg
# 2           20       RL         80.0     9600   Pave  Missing      Reg
# 3           60       RL         68.0    11250   Pave  Missing      IR1
# 4           70       RL         60.0     9550   Pave  Missing      IR1
# 5           60       RL         84.0    14260   Pave  Missing      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2          Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 3          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 4          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 5          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1        Norm     1Fam     2Story            7            5       2003
# 2        Norm     1Fam     1Story            6            8       1976
# 3        Norm     1Fam     2Story            7            5       2001
# 4        Norm     1Fam     2Story            7            5       1915
# 5        Norm     1Fam     2Story            8            5       2000
#
#     YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1           2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 2           1976     Gable  CompShg     MetalSd     MetalSd       None
# 3           2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 4           1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 5           2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#     MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# Id
# 1        196.0        Gd        TA      PConc       Gd       TA           No
# 2          0.0        TA        TA     CBlock       Gd       TA           Gd
# 3        162.0        Gd        TA      PConc       Gd       TA           Mn
# 4          0.0        TA        TA     BrkTil       TA       Gd           No
# 5        350.0        Gd        TA      PConc       Gd       TA           Av
#
#    BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# Id
# 1           GLQ         706          Unf           0        150          856
# 2           ALQ         978          Unf           0        284         1262
# 3           GLQ         486          Unf           0        434          920
# 4           ALQ         216          Unf           0        540          756
# 5           GLQ         655          Unf           0        490         1145
#
#    Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# Id
# 1     GasA        Ex          Y      SBrkr       856       854             0
# 2     GasA        Ex          Y      SBrkr      1262         0             0
# 3     GasA        Ex          Y      SBrkr       920       866             0
# 4     GasA        Gd          Y      SBrkr       961       756             0
# 5     GasA        Ex          Y      SBrkr      1145      1053             0
#
#     GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# Id
# 1        1710             1             0         2         1             3
# 2        1262             0             1         2         0             3
# 3        1786             1             0         2         1             3
# 4        1717             1             0         1         0             3
# 5        2198             1             0         2         1             4
#
#     KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# Id
# 1              1          Gd             8        Typ           0     Missing
# 2              1          TA             6        Typ           1          TA
# 3              1          Gd             6        Typ           1          TA
# 4              1          Gd             7        Typ           1          Gd
# 5              1          Gd             9        Typ           1          TA
#
#    GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# Id
# 1      Attchd       2003.0          RFn           2         548         TA
# 2      Attchd       1976.0          RFn           2         460         TA
# 3      Attchd       2001.0          RFn           2         608         TA
# 4      Detchd       1998.0          Unf           3         642         TA
# 5      Attchd       2000.0          RFn           3         836         TA
#
#    GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 1          TA          Y           0           61              0          0
# 2          TA          Y         298            0              0          0
# 3          TA          Y           0           42              0          0
# 4          TA          Y           0           35            272          0
# 5          TA          Y         192           84              0          0
#
#     ScreenPorch  PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  \
# Id
# 1             0         0  Missing  Missing     Missing        0       2
# 2             0         0  Missing  Missing     Missing        0       5
# 3             0         0  Missing  Missing     Missing        0       9
# 4             0         0  Missing  Missing     Missing        0       2
# 5             0         0  Missing  Missing     Missing        0      12
#
#     YrSold SaleType SaleCondition  SalePrice  LotFrontage_NaN  GarageYrBlt_NaN
# Id
# 1     2008       WD        Normal     208500                0                0
# 2     2007       WD        Normal     181500                0                0
# 3     2008       WD        Normal     223500                0                0
# 4     2006       WD       Abnorml     140000                0                0
# 5     2008       WD        Normal     250000                0                0

# %% [markdown]
# #### Handling Missing/NaN Values in Temporal Features (Datetime/Year Features)

# %%
# Extracting features with years 
year_features = [feature for feature in df.columns if ('Yr' in feature or 'Year' in feature) and 'NaN' not in feature]
year_features
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
# Converting year into age for first 3 features (in year_features) by taking difference between 'YrSold' and the feature
for feature in year_features[:-1]:
    df[feature] = df['YrSold'] - df[feature]
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave  Missing      Reg
# 2           20       RL         80.0     9600   Pave  Missing      Reg
# 3           60       RL         68.0    11250   Pave  Missing      IR1
# 4           70       RL         60.0     9550   Pave  Missing      IR1
# 5           60       RL         84.0    14260   Pave  Missing      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2          Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 3          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 4          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 5          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1        Norm     1Fam     2Story            7            5          5
# 2        Norm     1Fam     1Story            6            8         31
# 3        Norm     1Fam     2Story            7            5          7
# 4        Norm     1Fam     2Story            7            5         91
# 5        Norm     1Fam     2Story            8            5          8
#
#     YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1              5     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 2             31     Gable  CompShg     MetalSd     MetalSd       None
# 3              6     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 4             36     Gable  CompShg     Wd Sdng     Wd Shng       None
# 5              8     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#     MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# Id
# 1        196.0        Gd        TA      PConc       Gd       TA           No
# 2          0.0        TA        TA     CBlock       Gd       TA           Gd
# 3        162.0        Gd        TA      PConc       Gd       TA           Mn
# 4          0.0        TA        TA     BrkTil       TA       Gd           No
# 5        350.0        Gd        TA      PConc       Gd       TA           Av
#
#    BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# Id
# 1           GLQ         706          Unf           0        150          856
# 2           ALQ         978          Unf           0        284         1262
# 3           GLQ         486          Unf           0        434          920
# 4           ALQ         216          Unf           0        540          756
# 5           GLQ         655          Unf           0        490         1145
#
#    Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# Id
# 1     GasA        Ex          Y      SBrkr       856       854             0
# 2     GasA        Ex          Y      SBrkr      1262         0             0
# 3     GasA        Ex          Y      SBrkr       920       866             0
# 4     GasA        Gd          Y      SBrkr       961       756             0
# 5     GasA        Ex          Y      SBrkr      1145      1053             0
#
#     GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# Id
# 1        1710             1             0         2         1             3
# 2        1262             0             1         2         0             3
# 3        1786             1             0         2         1             3
# 4        1717             1             0         1         0             3
# 5        2198             1             0         2         1             4
#
#     KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# Id
# 1              1          Gd             8        Typ           0     Missing
# 2              1          TA             6        Typ           1          TA
# 3              1          Gd             6        Typ           1          TA
# 4              1          Gd             7        Typ           1          Gd
# 5              1          Gd             9        Typ           1          TA
#
#    GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# Id
# 1      Attchd          5.0          RFn           2         548         TA
# 2      Attchd         31.0          RFn           2         460         TA
# 3      Attchd          7.0          RFn           2         608         TA
# 4      Detchd          8.0          Unf           3         642         TA
# 5      Attchd          8.0          RFn           3         836         TA
#
#    GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 1          TA          Y           0           61              0          0
# 2          TA          Y         298            0              0          0
# 3          TA          Y           0           42              0          0
# 4          TA          Y           0           35            272          0
# 5          TA          Y         192           84              0          0
#
#     ScreenPorch  PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  \
# Id
# 1             0         0  Missing  Missing     Missing        0       2
# 2             0         0  Missing  Missing     Missing        0       5
# 3             0         0  Missing  Missing     Missing        0       9
# 4             0         0  Missing  Missing     Missing        0       2
# 5             0         0  Missing  Missing     Missing        0      12
#
#     YrSold SaleType SaleCondition  SalePrice  LotFrontage_NaN  GarageYrBlt_NaN
# Id
# 1     2008       WD        Normal     208500                0                0
# 2     2007       WD        Normal     181500                0                0
# 3     2008       WD        Normal     223500                0                0
# 4     2006       WD       Abnorml     140000                0                0
# 5     2008       WD        Normal     250000                0                0

# %% [markdown]
# - We can't work directly with year number here so instead of taking year value we convert it into number of years from the year os sale 'YrSold'
# - Basically we are kind of calculating age (in years)
# - Technically, from 'YearBuilt' we get 'House_Age', from 'YearRemodAdd' we get 'Remoddeling_Age' and from 'GarageYrBlt' we get 'Garage_Age'

# %%
# Printing specific columns from dataframe after updation
df[year_features].head()
# Out:
#     YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# Id
# 1           5             5          5.0    2008
# 2          31            31         31.0    2007
# 3           7             6          7.0    2008
# 4          91            36          8.0    2006
# 5           8             8          8.0    2008

# %% [markdown]
# #### Handling Skewed Continous Numerical Features

# %% [markdown]
# - In EDA, we saw that the continous numerical features are skewed, so we need to apply some transformation to convert them roughly into a standard normal distribution
# - We will apply logarithmic transformation specifically using the np.log(), only on numerical features which do not contain 0 in them as log(0) is not defined

# %%
# Extracting continous numerical features 
continous_numerical_features = [feature for feature in df.columns 
                                if df[feature].dtype != 'O' and feature not in year_features and df[feature].nunique() >= 25]

for feature in continous_numerical_features:
    if 0 not in df[feature].unique():
        df[feature] = np.log(df[feature])
        
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# Id
# 1           60       RL     4.174387  9.041922   Pave  Missing      Reg
# 2           20       RL     4.382027  9.169518   Pave  Missing      Reg
# 3           60       RL     4.219508  9.328123   Pave  Missing      IR1
# 4           70       RL     4.094345  9.164296   Pave  Missing      IR1
# 5           60       RL     4.430817  9.565214   Pave  Missing      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2          Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 3          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 4          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 5          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1        Norm     1Fam     2Story            7            5          5
# 2        Norm     1Fam     1Story            6            8         31
# 3        Norm     1Fam     2Story            7            5          7
# 4        Norm     1Fam     2Story            7            5         91
# 5        Norm     1Fam     2Story            8            5          8
#
#     YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1              5     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 2             31     Gable  CompShg     MetalSd     MetalSd       None
# 3              6     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 4             36     Gable  CompShg     Wd Sdng     Wd Shng       None
# 5              8     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#     MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# Id
# 1        196.0        Gd        TA      PConc       Gd       TA           No
# 2          0.0        TA        TA     CBlock       Gd       TA           Gd
# 3        162.0        Gd        TA      PConc       Gd       TA           Mn
# 4          0.0        TA        TA     BrkTil       TA       Gd           No
# 5        350.0        Gd        TA      PConc       Gd       TA           Av
#
#    BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# Id
# 1           GLQ         706          Unf           0        150          856
# 2           ALQ         978          Unf           0        284         1262
# 3           GLQ         486          Unf           0        434          920
# 4           ALQ         216          Unf           0        540          756
# 5           GLQ         655          Unf           0        490         1145
#
#    Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# Id
# 1     GasA        Ex          Y      SBrkr  6.752270       854             0
# 2     GasA        Ex          Y      SBrkr  7.140453         0             0
# 3     GasA        Ex          Y      SBrkr  6.824374       866             0
# 4     GasA        Gd          Y      SBrkr  6.867974       756             0
# 5     GasA        Ex          Y      SBrkr  7.043160      1053             0
#
#     GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# Id
# 1    7.444249             1             0         2         1             3
# 2    7.140453             0             1         2         0             3
# 3    7.487734             1             0         2         1             3
# 4    7.448334             1             0         1         0             3
# 5    7.695303             1             0         2         1             4
#
#     KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# Id
# 1              1          Gd             8        Typ           0     Missing
# 2              1          TA             6        Typ           1          TA
# 3              1          Gd             6        Typ           1          TA
# 4              1          Gd             7        Typ           1          Gd
# 5              1          Gd             9        Typ           1          TA
#
#    GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# Id
# 1      Attchd          5.0          RFn           2         548         TA
# 2      Attchd         31.0          RFn           2         460         TA
# 3      Attchd          7.0          RFn           2         608         TA
# 4      Detchd          8.0          Unf           3         642         TA
# 5      Attchd          8.0          RFn           3         836         TA
#
#    GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 1          TA          Y           0           61              0          0
# 2          TA          Y         298            0              0          0
# 3          TA          Y           0           42              0          0
# 4          TA          Y           0           35            272          0
# 5          TA          Y         192           84              0          0
#
#     ScreenPorch  PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  \
# Id
# 1             0         0  Missing  Missing     Missing        0       2
# 2             0         0  Missing  Missing     Missing        0       5
# 3             0         0  Missing  Missing     Missing        0       9
# 4             0         0  Missing  Missing     Missing        0       2
# 5             0         0  Missing  Missing     Missing        0      12
#
#     YrSold SaleType SaleCondition  SalePrice  LotFrontage_NaN  GarageYrBlt_NaN
# Id
# 1     2008       WD        Normal  12.247694                0                0
# 2     2007       WD        Normal  12.109011                0                0
# 3     2008       WD        Normal  12.317167                0                0
# 4     2006       WD       Abnorml  11.849398                0                0
# 5     2008       WD        Normal  12.429216                0                0

# %% [markdown]
# #### Handling Rare Categories in Categorical Features

# %% [markdown]
# - We will remove the categories in a feature that are present less than 1% of the total observations
# - This can be done because these categories (in a particular feature) do not have much weight or much impact on the prediction
# - Instead we will replace these rare categories with a new label called 'Rare_Var'

# %%
# Extracting categorical variables
# No need to account for year_features as they are a number now
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O'] 
print(categorical_features)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
# Replacing rare categories in all categorical features by label 'Rare_Var'
for feature in categorical_features:
    temp = df.groupby(feature)['SalePrice'].count()/len(df)
    indices = temp[temp > 0.01].index
    df[feature] = np.where(df[feature].isin(indices), df[feature], 'Rare_Var')

df.head(10)
# Out:
#     MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# Id
# 1           60       RL     4.174387  9.041922   Pave  Missing      Reg
# 2           20       RL     4.382027  9.169518   Pave  Missing      Reg
# 3           60       RL     4.219508  9.328123   Pave  Missing      IR1
# 4           70       RL     4.094345  9.164296   Pave  Missing      IR1
# 5           60       RL     4.430817  9.565214   Pave  Missing      IR1
# 6           50       RL     4.442651  9.554993   Pave  Missing      IR1
# 7           20       RL     4.317488  9.218705   Pave  Missing      Reg
# 8           60       RL     4.234107  9.247829   Pave  Missing      IR1
# 9           50       RM     3.931826  8.719317   Pave  Missing      Reg
# 10         190       RL     3.912023  8.911934   Pave  Missing      Reg
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2          Lvl    AllPub       FR2       Gtl     Rare_Var      Feedr
# 3          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 4          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 5          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# 6          Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 7          Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 8          Lvl    AllPub    Corner       Gtl       NWAmes       PosN
# 9          Lvl    AllPub    Inside       Gtl      OldTown     Artery
# 10         Lvl    AllPub    Corner       Gtl      BrkSide     Artery
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1        Norm     1Fam     2Story            7            5          5
# 2        Norm     1Fam     1Story            6            8         31
# 3        Norm     1Fam     2Story            7            5          7
# 4        Norm     1Fam     2Story            7            5         91
# 5        Norm     1Fam     2Story            8            5          8
# 6        Norm     1Fam     1.5Fin            5            5         16
# 7        Norm     1Fam     1Story            8            5          3
# 8        Norm     1Fam     2Story            7            6         36
# 9        Norm     1Fam     1.5Fin            7            5         77
# 10   Rare_Var   2fmCon   Rare_Var            5            6         69
#
#     YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1              5     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 2             31     Gable  CompShg     MetalSd     MetalSd       None
# 3              6     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 4             36     Gable  CompShg     Wd Sdng     Wd Shng       None
# 5              8     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 6             14     Gable  CompShg     VinylSd     VinylSd       None
# 7              2     Gable  CompShg     VinylSd     VinylSd      Stone
# 8             36     Gable  CompShg     HdBoard     HdBoard      Stone
# 9             58     Gable  CompShg     BrkFace     Wd Shng       None
# 10            58     Gable  CompShg     MetalSd     MetalSd       None
#
#     MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# Id
# 1        196.0        Gd        TA      PConc       Gd       TA           No
# 2          0.0        TA        TA     CBlock       Gd       TA           Gd
# 3        162.0        Gd        TA      PConc       Gd       TA           Mn
# 4          0.0        TA        TA     BrkTil       TA       Gd           No
# 5        350.0        Gd        TA      PConc       Gd       TA           Av
# 6          0.0        TA        TA   Rare_Var       Gd       TA           No
# 7        186.0        Gd        TA      PConc       Ex       TA           Av
# 8        240.0        TA        TA     CBlock       Gd       TA           Mn
# 9          0.0        TA        TA     BrkTil       TA       TA           No
# 10         0.0        TA        TA     BrkTil       TA       TA           No
#
#    BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# Id
# 1           GLQ         706          Unf           0        150          856
# 2           ALQ         978          Unf           0        284         1262
# 3           GLQ         486          Unf           0        434          920
# 4           ALQ         216          Unf           0        540          756
# 5           GLQ         655          Unf           0        490         1145
# 6           GLQ         732          Unf           0         64          796
# 7           GLQ        1369          Unf           0        317         1686
# 8           ALQ         859          BLQ          32        216         1107
# 9           Unf           0          Unf           0        952          952
# 10          GLQ         851          Unf           0        140          991
#
#    Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# Id
# 1     GasA        Ex          Y      SBrkr  6.752270       854             0
# 2     GasA        Ex          Y      SBrkr  7.140453         0             0
# 3     GasA        Ex          Y      SBrkr  6.824374       866             0
# 4     GasA        Gd          Y      SBrkr  6.867974       756             0
# 5     GasA        Ex          Y      SBrkr  7.043160      1053             0
# 6     GasA        Ex          Y      SBrkr  6.679599       566             0
# 7     GasA        Ex          Y      SBrkr  7.434848         0             0
# 8     GasA        Ex          Y      SBrkr  7.009409       983             0
# 9     GasA        Gd          Y      FuseF  6.929517       752             0
# 10    GasA        Ex          Y      SBrkr  6.981935         0             0
#
#     GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# Id
# 1    7.444249             1             0         2         1             3
# 2    7.140453             0             1         2         0             3
# 3    7.487734             1             0         2         1             3
# 4    7.448334             1             0         1         0             3
# 5    7.695303             1             0         2         1             4
# 6    7.216709             1             0         1         1             1
# 7    7.434848             1             0         2         0             3
# 8    7.644919             1             0         2         1             3
# 9    7.480992             0             0         2         0             2
# 10   6.981935             1             0         1         0             2
#
#     KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# Id
# 1              1          Gd             8        Typ           0     Missing
# 2              1          TA             6        Typ           1          TA
# 3              1          Gd             6        Typ           1          TA
# 4              1          Gd             7        Typ           1          Gd
# 5              1          Gd             9        Typ           1          TA
# 6              1          TA             5        Typ           0     Missing
# 7              1          Gd             7        Typ           1          Gd
# 8              1          TA             7        Typ           2          TA
# 9              2          TA             8       Min1           2          TA
# 10             2          TA             5        Typ           2          TA
#
#    GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# Id
# 1      Attchd          5.0          RFn           2         548         TA
# 2      Attchd         31.0          RFn           2         460         TA
# 3      Attchd          7.0          RFn           2         608         TA
# 4      Detchd          8.0          Unf           3         642         TA
# 5      Attchd          8.0          RFn           3         836         TA
# 6      Attchd         16.0          Unf           2         480         TA
# 7      Attchd          3.0          RFn           2         636         TA
# 8      Attchd         36.0          RFn           2         484         TA
# 9      Detchd         77.0          Unf           2         468         Fa
# 10     Attchd         69.0          RFn           1         205   Rare_Var
#
#    GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 1          TA          Y           0           61              0          0
# 2          TA          Y         298            0              0          0
# 3          TA          Y           0           42              0          0
# 4          TA          Y           0           35            272          0
# 5          TA          Y         192           84              0          0
# 6          TA          Y          40           30              0        320
# 7          TA          Y         255           57              0          0
# 8          TA          Y         235          204            228          0
# 9          TA          Y          90            0            205          0
# 10         TA          Y           0            4              0          0
#
#     ScreenPorch  PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  \
# Id
# 1             0         0  Missing  Missing     Missing        0       2
# 2             0         0  Missing  Missing     Missing        0       5
# 3             0         0  Missing  Missing     Missing        0       9
# 4             0         0  Missing  Missing     Missing        0       2
# 5             0         0  Missing  Missing     Missing        0      12
# 6             0         0  Missing    MnPrv        Shed      700      10
# 7             0         0  Missing  Missing     Missing        0       8
# 8             0         0  Missing  Missing        Shed      350      11
# 9             0         0  Missing  Missing     Missing        0       4
# 10            0         0  Missing  Missing     Missing        0       1
#
#     YrSold SaleType SaleCondition  SalePrice  LotFrontage_NaN  GarageYrBlt_NaN
# Id
# 1     2008       WD        Normal  12.247694                0                0
# 2     2007       WD        Normal  12.109011                0                0
# 3     2008       WD        Normal  12.317167                0                0
# 4     2006       WD       Abnorml  11.849398                0                0
# 5     2008       WD        Normal  12.429216                0                0
# 6     2009       WD        Normal  11.870600                0                0
# 7     2007       WD        Normal  12.634603                0                0
# 8     2009       WD        Normal  12.206073                1                0
# 9     2008       WD       Abnorml  11.774520                0                0
# 10    2008       WD        Normal  11.678440                0                0

# %% [markdown]
# #### Applying Label Encodig

# %%
# Applying label encoder on each categorical feature to convert it from string to number
for feature in categorical_features:
    encoder = LabelEncoder()
    df[feature] = encoder.fit_transform(df[feature])
df.head()
# Out:
#     MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# Id
# 1           60         2     4.174387  9.041922       0      1         3
# 2           20         2     4.382027  9.169518       0      1         3
# 3           60         2     4.219508  9.328123       0      1         0
# 4           70         2     4.094345  9.164296       0      1         0
# 5           60         2     4.430817  9.565214       0      1         0
#
#     LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# Id
# 1             3          0          3          0             4           2
# 2             3          0          2          0            16           1
# 3             3          0          3          0             4           2
# 4             3          0          0          0             5           2
# 5             3          0          2          0            13           2
#
#     Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1            0         0           2            7            5          5
# 2            0         0           1            6            8         31
# 3            0         0           2            7            5          7
# 4            0         0           2            7            5         91
# 5            0         0           2            8            5          8
#
#     YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  \
# Id
# 1              5          0         0            8            8           1
# 2             31          0         0            4            4           2
# 3              6          0         0            8            8           1
# 4             36          0         0            9           10           2
# 5              8          0         0            8            8           1
#
#     MasVnrArea  ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  \
# Id
# 1        196.0          1          3           2         2         4
# 2          0.0          3          3           1         2         4
# 3        162.0          1          3           2         2         4
# 4          0.0          3          3           0         4         1
# 5        350.0          1          3           2         2         4
#
#     BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  BsmtFinSF2  \
# Id
# 1              4             2         706             6           0
# 2              1             0         978             6           0
# 3              3             2         486             6           0
# 4              4             0         216             6           0
# 5              0             2         655             6           0
#
#     BsmtUnfSF  TotalBsmtSF  Heating  HeatingQC  CentralAir  Electrical  \
# Id
# 1         150          856        0          0           1           3
# 2         284         1262        0          0           1           3
# 3         434          920        0          0           1           3
# 4         540          756        0          2           1           3
# 5         490         1145        0          0           1           3
#
#     1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1   6.752270       854             0   7.444249             1             0
# 2   7.140453         0             0   7.140453             0             1
# 3   6.824374       866             0   7.487734             1             0
# 4   6.867974       756             0   7.448334             1             0
# 5   7.043160      1053             0   7.695303             1             0
#
#     FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  KitchenQual  TotRmsAbvGrd  \
# Id
# 1          2         1             3             1            2             8
# 2          2         0             3             1            3             6
# 3          2         1             3             1            2             6
# 4          1         0             3             1            2             7
# 5          2         1             4             1            2             9
#
#     Functional  Fireplaces  FireplaceQu  GarageType  GarageYrBlt  \
# Id
# 1            4           0            3           0          5.0
# 2            4           1            5           0         31.0
# 3            4           1            5           0          7.0
# 4            4           1            2           3          8.0
# 5            4           1            5           0          8.0
#
#     GarageFinish  GarageCars  GarageArea  GarageQual  GarageCond  PavedDrive  \
# Id
# 1              2           2         548           3           3           2
# 2              2           2         460           3           3           2
# 3              2           2         608           3           3           2
# 4              3           3         642           3           3           2
# 5              2           3         836           3           3           2
#
#     WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# Id
# 1            0           61              0          0            0         0
# 2          298            0              0          0            0         0
# 3            0           42              0          0            0         0
# 4            0           35            272          0            0         0
# 5          192           84              0          0            0         0
#
#     PoolQC  Fence  MiscFeature  MiscVal  MoSold  YrSold  SaleType  \
# Id
# 1        0      2            0        0       2    2008         3
# 2        0      2            0        0       5    2007         3
# 3        0      2            0        0       9    2008         3
# 4        0      2            0        0       2    2006         3
# 5        0      2            0        0      12    2008         3
#
#     SaleCondition  SalePrice  LotFrontage_NaN  GarageYrBlt_NaN
# Id
# 1               2  12.247694                0                0
# 2               2  12.109011                0                0
# 3               2  12.317167                0                0
# 4               0  11.849398                0                0
# 5               2  12.429216                0                0

# %% [markdown]
# - We have converted categorical features with string/object datatype into numbers using LabelEncoder
# - In categorical features, just assign a number to each unique category, so that now in a particular feature each unique category is represented by that number everywhere instead of the string value

# %% [markdown]
# #### Applying Feature Scaling

# %%
# Extracting X_train and y_train variables from the dataframe
X_train = df.drop(['SalePrice'], axis=1)
y_train = df[['SalePrice']]
y_train.head()
# Out:
#     SalePrice
# Id
# 1   12.247694
# 2   12.109011
# 3   12.317167
# 4   11.849398
# 5   12.429216

# %%
# Scaling features using MinMaxScaler
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns, index=y_train.index)
X_train.head()
# Out:
#     MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# Id
# 1     0.235294       0.5     0.418208  0.366344     0.0    0.5       1.0
# 2     0.000000       0.5     0.495064  0.391317     0.0    0.5       1.0
# 3     0.235294       0.5     0.434909  0.422359     0.0    0.5       0.0
# 4     0.294118       0.5     0.388581  0.390295     0.0    0.5       0.0
# 5     0.235294       0.5     0.513123  0.468761     0.0    0.5       0.0
#
#     LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# Id
# 1           1.0        0.0       0.75        0.0      0.181818         0.4
# 2           1.0        0.0       0.50        0.0      0.727273         0.2
# 3           1.0        0.0       0.75        0.0      0.181818         0.4
# 4           1.0        0.0       0.00        0.0      0.227273         0.4
# 5           1.0        0.0       0.50        0.0      0.590909         0.4
#
#     Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1          0.0       0.0         0.4     0.666667        0.500   0.036765
# 2          0.0       0.0         0.2     0.555556        0.875   0.227941
# 3          0.0       0.0         0.4     0.666667        0.500   0.051471
# 4          0.0       0.0         0.4     0.666667        0.500   0.669118
# 5          0.0       0.0         0.4     0.777778        0.500   0.058824
#
#     YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  \
# Id
# 1       0.098361        0.0       0.0          0.8          0.8        0.25
# 2       0.524590        0.0       0.0          0.4          0.4        0.50
# 3       0.114754        0.0       0.0          0.8          0.8        0.25
# 4       0.606557        0.0       0.0          0.9          1.0        0.50
# 5       0.147541        0.0       0.0          0.8          0.8        0.25
#
#     MasVnrArea  ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  \
# Id
# 1      0.12250   0.333333        1.0        0.50       0.5      1.00
# 2      0.00000   1.000000        1.0        0.25       0.5      1.00
# 3      0.10125   0.333333        1.0        0.50       0.5      1.00
# 4      0.00000   1.000000        1.0        0.00       1.0      0.25
# 5      0.21875   0.333333        1.0        0.50       0.5      1.00
#
#     BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  BsmtFinSF2  \
# Id
# 1           1.00      0.333333    0.125089           1.0         0.0
# 2           0.25      0.000000    0.173281           1.0         0.0
# 3           0.75      0.333333    0.086109           1.0         0.0
# 4           1.00      0.000000    0.038271           1.0         0.0
# 5           0.00      0.333333    0.116052           1.0         0.0
#
#     BsmtUnfSF  TotalBsmtSF  Heating  HeatingQC  CentralAir  Electrical  \
# Id
# 1    0.064212     0.140098      0.0        0.0         1.0         1.0
# 2    0.121575     0.206547      0.0        0.0         1.0         1.0
# 3    0.185788     0.150573      0.0        0.0         1.0         1.0
# 4    0.231164     0.123732      0.0        0.5         1.0         1.0
# 5    0.209760     0.187398      0.0        0.0         1.0         1.0
#
#     1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1   0.356155  0.413559           0.0   0.577712      0.333333           0.0
# 2   0.503056  0.000000           0.0   0.470245      0.000000           0.5
# 3   0.383441  0.419370           0.0   0.593095      0.333333           0.0
# 4   0.399941  0.366102           0.0   0.579157      0.333333           0.0
# 5   0.466237  0.509927           0.0   0.666523      0.333333           0.0
#
#     FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  KitchenQual  TotRmsAbvGrd  \
# Id
# 1   0.666667       0.5         0.375      0.333333     0.666667      0.500000
# 2   0.666667       0.0         0.375      0.333333     1.000000      0.333333
# 3   0.666667       0.5         0.375      0.333333     0.666667      0.333333
# 4   0.333333       0.0         0.375      0.333333     0.666667      0.416667
# 5   0.666667       0.5         0.500      0.333333     0.666667      0.583333
#
#     Functional  Fireplaces  FireplaceQu  GarageType  GarageYrBlt  \
# Id
# 1          1.0    0.000000          0.6         0.0     0.046729
# 2          1.0    0.333333          1.0         0.0     0.289720
# 3          1.0    0.333333          1.0         0.0     0.065421
# 4          1.0    0.333333          0.4         0.6     0.074766
# 5          1.0    0.333333          1.0         0.0     0.074766
#
#     GarageFinish  GarageCars  GarageArea  GarageQual  GarageCond  PavedDrive  \
# Id
# 1       0.666667        0.50    0.386460         1.0         1.0         1.0
# 2       0.666667        0.50    0.324401         1.0         1.0         1.0
# 3       0.666667        0.50    0.428773         1.0         1.0         1.0
# 4       1.000000        0.75    0.452750         1.0         1.0         1.0
# 5       0.666667        0.75    0.589563         1.0         1.0         1.0
#
#     WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# Id
# 1     0.000000     0.111517       0.000000        0.0          0.0       0.0
# 2     0.347725     0.000000       0.000000        0.0          0.0       0.0
# 3     0.000000     0.076782       0.000000        0.0          0.0       0.0
# 4     0.000000     0.063985       0.492754        0.0          0.0       0.0
# 5     0.224037     0.153565       0.000000        0.0          0.0       0.0
#
#     PoolQC  Fence  MiscFeature  MiscVal    MoSold  YrSold  SaleType  \
# Id
# 1      0.0    0.5          0.0      0.0  0.090909    0.50       1.0
# 2      0.0    0.5          0.0      0.0  0.363636    0.25       1.0
# 3      0.0    0.5          0.0      0.0  0.727273    0.50       1.0
# 4      0.0    0.5          0.0      0.0  0.090909    0.00       1.0
# 5      0.0    0.5          0.0      0.0  1.000000    0.50       1.0
#
#     SaleCondition  LotFrontage_NaN  GarageYrBlt_NaN
# Id
# 1             0.5              0.0              0.0
# 2             0.5              0.0              0.0
# 3             0.5              0.0              0.0
# 4             0.0              0.0              0.0
# 5             0.5              0.0              0.0

# %% [markdown]
# - We have used MinMaxScaler instead of StandardScaler because in our dataset there aren't any negative values, so appyling StandardScaler does not make much sense
# - Although StandardScaler will also work fine on our problem but MinMaxscaler will perform better

# %%
# Dumping the MinMaxScaler learnt to a pickle file
pickle_file = open('minmax_scaler.pkl', 'wb')
pickle.dump(scaler, pickle_file)
pickle_file.close()

# %% [markdown]
# #### Exporting Processed Train Data

# %%
# Concatenating X_train and y_train
df = pd.concat([X_train, y_train], axis=1)
df.head()
# Out:
#     MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# Id
# 1     0.235294       0.5     0.418208  0.366344     0.0    0.5       1.0
# 2     0.000000       0.5     0.495064  0.391317     0.0    0.5       1.0
# 3     0.235294       0.5     0.434909  0.422359     0.0    0.5       0.0
# 4     0.294118       0.5     0.388581  0.390295     0.0    0.5       0.0
# 5     0.235294       0.5     0.513123  0.468761     0.0    0.5       0.0
#
#     LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# Id
# 1           1.0        0.0       0.75        0.0      0.181818         0.4
# 2           1.0        0.0       0.50        0.0      0.727273         0.2
# 3           1.0        0.0       0.75        0.0      0.181818         0.4
# 4           1.0        0.0       0.00        0.0      0.227273         0.4
# 5           1.0        0.0       0.50        0.0      0.590909         0.4
#
#     Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1          0.0       0.0         0.4     0.666667        0.500   0.036765
# 2          0.0       0.0         0.2     0.555556        0.875   0.227941
# 3          0.0       0.0         0.4     0.666667        0.500   0.051471
# 4          0.0       0.0         0.4     0.666667        0.500   0.669118
# 5          0.0       0.0         0.4     0.777778        0.500   0.058824
#
#     YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  \
# Id
# 1       0.098361        0.0       0.0          0.8          0.8        0.25
# 2       0.524590        0.0       0.0          0.4          0.4        0.50
# 3       0.114754        0.0       0.0          0.8          0.8        0.25
# 4       0.606557        0.0       0.0          0.9          1.0        0.50
# 5       0.147541        0.0       0.0          0.8          0.8        0.25
#
#     MasVnrArea  ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  \
# Id
# 1      0.12250   0.333333        1.0        0.50       0.5      1.00
# 2      0.00000   1.000000        1.0        0.25       0.5      1.00
# 3      0.10125   0.333333        1.0        0.50       0.5      1.00
# 4      0.00000   1.000000        1.0        0.00       1.0      0.25
# 5      0.21875   0.333333        1.0        0.50       0.5      1.00
#
#     BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  BsmtFinSF2  \
# Id
# 1           1.00      0.333333    0.125089           1.0         0.0
# 2           0.25      0.000000    0.173281           1.0         0.0
# 3           0.75      0.333333    0.086109           1.0         0.0
# 4           1.00      0.000000    0.038271           1.0         0.0
# 5           0.00      0.333333    0.116052           1.0         0.0
#
#     BsmtUnfSF  TotalBsmtSF  Heating  HeatingQC  CentralAir  Electrical  \
# Id
# 1    0.064212     0.140098      0.0        0.0         1.0         1.0
# 2    0.121575     0.206547      0.0        0.0         1.0         1.0
# 3    0.185788     0.150573      0.0        0.0         1.0         1.0
# 4    0.231164     0.123732      0.0        0.5         1.0         1.0
# 5    0.209760     0.187398      0.0        0.0         1.0         1.0
#
#     1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1   0.356155  0.413559           0.0   0.577712      0.333333           0.0
# 2   0.503056  0.000000           0.0   0.470245      0.000000           0.5
# 3   0.383441  0.419370           0.0   0.593095      0.333333           0.0
# 4   0.399941  0.366102           0.0   0.579157      0.333333           0.0
# 5   0.466237  0.509927           0.0   0.666523      0.333333           0.0
#
#     FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  KitchenQual  TotRmsAbvGrd  \
# Id
# 1   0.666667       0.5         0.375      0.333333     0.666667      0.500000
# 2   0.666667       0.0         0.375      0.333333     1.000000      0.333333
# 3   0.666667       0.5         0.375      0.333333     0.666667      0.333333
# 4   0.333333       0.0         0.375      0.333333     0.666667      0.416667
# 5   0.666667       0.5         0.500      0.333333     0.666667      0.583333
#
#     Functional  Fireplaces  FireplaceQu  GarageType  GarageYrBlt  \
# Id
# 1          1.0    0.000000          0.6         0.0     0.046729
# 2          1.0    0.333333          1.0         0.0     0.289720
# 3          1.0    0.333333          1.0         0.0     0.065421
# 4          1.0    0.333333          0.4         0.6     0.074766
# 5          1.0    0.333333          1.0         0.0     0.074766
#
#     GarageFinish  GarageCars  GarageArea  GarageQual  GarageCond  PavedDrive  \
# Id
# 1       0.666667        0.50    0.386460         1.0         1.0         1.0
# 2       0.666667        0.50    0.324401         1.0         1.0         1.0
# 3       0.666667        0.50    0.428773         1.0         1.0         1.0
# 4       1.000000        0.75    0.452750         1.0         1.0         1.0
# 5       0.666667        0.75    0.589563         1.0         1.0         1.0
#
#     WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# Id
# 1     0.000000     0.111517       0.000000        0.0          0.0       0.0
# 2     0.347725     0.000000       0.000000        0.0          0.0       0.0
# 3     0.000000     0.076782       0.000000        0.0          0.0       0.0
# 4     0.000000     0.063985       0.492754        0.0          0.0       0.0
# 5     0.224037     0.153565       0.000000        0.0          0.0       0.0
#
#     PoolQC  Fence  MiscFeature  MiscVal    MoSold  YrSold  SaleType  \
# Id
# 1      0.0    0.5          0.0      0.0  0.090909    0.50       1.0
# 2      0.0    0.5          0.0      0.0  0.363636    0.25       1.0
# 3      0.0    0.5          0.0      0.0  0.727273    0.50       1.0
# 4      0.0    0.5          0.0      0.0  0.090909    0.00       1.0
# 5      0.0    0.5          0.0      0.0  1.000000    0.50       1.0
#
#     SaleCondition  LotFrontage_NaN  GarageYrBlt_NaN  SalePrice
# Id
# 1             0.5              0.0              0.0  12.247694
# 2             0.5              0.0              0.0  12.109011
# 3             0.5              0.0              0.0  12.317167
# 4             0.0              0.0              0.0  11.849398
# 5             0.5              0.0              0.0  12.429216

# %%
# Exporting Train Data to CSV file
df.to_csv('train_preprocessed.csv')

# %% [markdown]
# - We have concatenated the X_train and y_train to create the final training dataset
# - And then we export it to the current directory in CSV format

# %% [markdown]
# ### Test Data

# %% [markdown]
# - Now we apply the exact same feature engineering steps to the test data
# - Steps to follow as per train data:
#     - Import test data
#     - Handle NaN values in numerical features
#     - Handle NaN values in categorical features
#     - Handle NaN values in temporal features
#     - Handle skewed continous numerical features
#     - Handle rare categories in categorical features
#     - Apply label encoding
#     - Apply feature scaling
#     - Export processed test data

# %% [markdown]
# #### Importing Test Data

# %%
# Importing test data
df_test = pd.read_csv('test.csv', index_col='Id')
df_test.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1461         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1462         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 1463         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1464         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1465         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1461       Norm     1Fam     1Story            5            6       1961
# 1462       Norm     1Fam     1Story            6            6       1958
# 1463       Norm     1Fam     2Story            5            5       1997
# 1464       Norm     1Fam     2Story            6            6       1998
# 1465       Norm   TwnhsE     1Story            8            5       1992
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1461          1961     Gable  CompShg     VinylSd     VinylSd       None
# 1462          1958       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 1463          1998     Gable  CompShg     VinylSd     VinylSd       None
# 1464          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1465          1992     Gable  CompShg     HdBoard     HdBoard       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 1461         0.0        TA        TA     CBlock       TA       TA
# 1462       108.0        TA        TA     CBlock       TA       TA
# 1463         0.0        TA        TA      PConc       Gd       TA
# 1464        20.0        TA        TA      PConc       TA       TA
# 1465         0.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 1461           No          Rec       468.0          LwQ       144.0
# 1462           No          ALQ       923.0          Unf         0.0
# 1463           No          GLQ       791.0          Unf         0.0
# 1464           No          GLQ       602.0          Unf         0.0
# 1465           No          ALQ       263.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 1461      270.0        882.0    GasA        TA          Y      SBrkr
# 1462      406.0       1329.0    GasA        TA          Y      SBrkr
# 1463      137.0        928.0    GasA        Gd          Y      SBrkr
# 1464      324.0        926.0    GasA        Ex          Y      SBrkr
# 1465     1017.0       1280.0    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1461       896         0             0        896           0.0           0.0
# 1462      1329         0             0       1329           0.0           0.0
# 1463       928       701             0       1629           0.0           0.0
# 1464       926       678             0       1604           0.0           0.0
# 1465      1280         0             0       1280           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 1461         1         0             2             1          TA
# 1462         1         1             3             1          Gd
# 1463         2         1             3             1          TA
# 1464         2         1             3             1          Gd
# 1465         2         0             2             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# Id
# 1461             5        Typ           0         NaN     Attchd       1961.0
# 1462             6        Typ           0         NaN     Attchd       1958.0
# 1463             6        Typ           1          TA     Attchd       1997.0
# 1464             7        Typ           1          Gd     Attchd       1998.0
# 1465             5        Typ           0         NaN     Attchd       1992.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# Id
# 1461          Unf         1.0       730.0         TA         TA          Y
# 1462          Unf         1.0       312.0         TA         TA          Y
# 1463          Fin         2.0       482.0         TA         TA          Y
# 1464          Fin         2.0       470.0         TA         TA          Y
# 1465          RFn         2.0       506.0         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 1461         140            0              0          0          120
# 1462         393           36              0          0            0
# 1463         212           34              0          0            0
# 1464         360           36              0          0            0
# 1465           0           82              0          0          144
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# Id
# 1461         0    NaN  MnPrv         NaN        0       6    2010       WD
# 1462         0    NaN    NaN        Gar2    12500       6    2010       WD
# 1463         0    NaN  MnPrv         NaN        0       3    2010       WD
# 1464         0    NaN    NaN         NaN        0       6    2010       WD
# 1465         0    NaN    NaN         NaN        0       1    2010       WD
#
#      SaleCondition
# Id
# 1461        Normal
# 1462        Normal
# 1463        Normal
# 1464        Normal
# 1465        Normal

# %%
# Printing shape of test data
df_test.shape
# Out:
# (1459, 79)

# %% [markdown]
# #### Handling Missing/NaN Values in Numerical Features

# %%
# Calculating percentage of NaN values (in columns with NaN values present) in numerical features
features_with_nan = [feature for feature in df_test.columns 
                     if df_test[feature].isnull().sum() > 0 and df_test[feature].dtype != 'O']

for feature in features_with_nan:
    print(feature, ':', round(df_test[feature].isnull().mean() * 100, 2), '%')
# Out:
# LotFrontage : 15.56 %
# MasVnrArea : 1.03 %
# BsmtFinSF1 : 0.07 %
# BsmtFinSF2 : 0.07 %
# BsmtUnfSF : 0.07 %
# TotalBsmtSF : 0.07 %
# BsmtFullBath : 0.14 %
# BsmtHalfBath : 0.14 %
# GarageYrBlt : 5.35 %
# GarageCars : 0.07 %
# GarageArea : 0.07 %

# %%
# Replacing NaN values with the median of that feature
for feature in features_with_nan:
    if feature == 'LotFrontage' or feature == 'GarageYrBlt':
        df_test[feature+'_NaN'] = np.where(df_test[feature].isnull(), 1, 0)
    df_test[feature] = df_test[feature].fillna(df_test[feature].median())
    
# Printing number of NaN values in numerical features after handling them
df_test[features_with_nan].isnull().sum()
# Out:
# LotFrontage     0
# MasVnrArea      0
# BsmtFinSF1      0
# BsmtFinSF2      0
# BsmtUnfSF       0
# TotalBsmtSF     0
# BsmtFullBath    0
# BsmtHalfBath    0
# GarageYrBlt     0
# GarageCars      0
# GarageArea      0
# dtype: int64

# %%
# Printing updated dataframe
df_test.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1461         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1462         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 1463         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1464         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1465         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1461       Norm     1Fam     1Story            5            6       1961
# 1462       Norm     1Fam     1Story            6            6       1958
# 1463       Norm     1Fam     2Story            5            5       1997
# 1464       Norm     1Fam     2Story            6            6       1998
# 1465       Norm   TwnhsE     1Story            8            5       1992
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1461          1961     Gable  CompShg     VinylSd     VinylSd       None
# 1462          1958       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 1463          1998     Gable  CompShg     VinylSd     VinylSd       None
# 1464          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1465          1992     Gable  CompShg     HdBoard     HdBoard       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 1461         0.0        TA        TA     CBlock       TA       TA
# 1462       108.0        TA        TA     CBlock       TA       TA
# 1463         0.0        TA        TA      PConc       Gd       TA
# 1464        20.0        TA        TA      PConc       TA       TA
# 1465         0.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 1461           No          Rec       468.0          LwQ       144.0
# 1462           No          ALQ       923.0          Unf         0.0
# 1463           No          GLQ       791.0          Unf         0.0
# 1464           No          GLQ       602.0          Unf         0.0
# 1465           No          ALQ       263.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 1461      270.0        882.0    GasA        TA          Y      SBrkr
# 1462      406.0       1329.0    GasA        TA          Y      SBrkr
# 1463      137.0        928.0    GasA        Gd          Y      SBrkr
# 1464      324.0        926.0    GasA        Ex          Y      SBrkr
# 1465     1017.0       1280.0    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1461       896         0             0        896           0.0           0.0
# 1462      1329         0             0       1329           0.0           0.0
# 1463       928       701             0       1629           0.0           0.0
# 1464       926       678             0       1604           0.0           0.0
# 1465      1280         0             0       1280           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 1461         1         0             2             1          TA
# 1462         1         1             3             1          Gd
# 1463         2         1             3             1          TA
# 1464         2         1             3             1          Gd
# 1465         2         0             2             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# Id
# 1461             5        Typ           0         NaN     Attchd       1961.0
# 1462             6        Typ           0         NaN     Attchd       1958.0
# 1463             6        Typ           1          TA     Attchd       1997.0
# 1464             7        Typ           1          Gd     Attchd       1998.0
# 1465             5        Typ           0         NaN     Attchd       1992.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# Id
# 1461          Unf         1.0       730.0         TA         TA          Y
# 1462          Unf         1.0       312.0         TA         TA          Y
# 1463          Fin         2.0       482.0         TA         TA          Y
# 1464          Fin         2.0       470.0         TA         TA          Y
# 1465          RFn         2.0       506.0         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 1461         140            0              0          0          120
# 1462         393           36              0          0            0
# 1463         212           34              0          0            0
# 1464         360           36              0          0            0
# 1465           0           82              0          0          144
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# Id
# 1461         0    NaN  MnPrv         NaN        0       6    2010       WD
# 1462         0    NaN    NaN        Gar2    12500       6    2010       WD
# 1463         0    NaN  MnPrv         NaN        0       3    2010       WD
# 1464         0    NaN    NaN         NaN        0       6    2010       WD
# 1465         0    NaN    NaN         NaN        0       1    2010       WD
#
#      SaleCondition  LotFrontage_NaN  GarageYrBlt_NaN
# Id
# 1461        Normal                0                0
# 1462        Normal                0                0
# 1463        Normal                0                0
# 1464        Normal                0                0
# 1465        Normal                0                0

# %% [markdown]
# #### Handling Missing/NaN Values in Categorical Features

# %%
# Calculating percentage of NaN values (in columns with NaN values present) in categorical features
features_with_nan = [feature for feature in df_test.columns 
                     if df_test[feature].isnull().sum() > 0 and df_test[feature].dtype == 'O']

for feature in features_with_nan:
    print(feature, ':', round(df_test[feature].isnull().mean() * 100, 2), '%')
# Out:
# MSZoning : 0.27 %
# Alley : 92.67 %
# Utilities : 0.14 %
# Exterior1st : 0.07 %
# Exterior2nd : 0.07 %
# MasVnrType : 1.1 %
# BsmtQual : 3.02 %
# BsmtCond : 3.08 %
# BsmtExposure : 3.02 %
# BsmtFinType1 : 2.88 %
# BsmtFinType2 : 2.88 %
# KitchenQual : 0.07 %
# Functional : 0.14 %
# FireplaceQu : 50.03 %
# GarageType : 5.21 %
# GarageFinish : 5.35 %
# GarageQual : 5.35 %
# GarageCond : 5.35 %
# PoolQC : 99.79 %
# Fence : 80.12 %
# MiscFeature : 96.5 %
# SaleType : 0.07 %

# %%
# Replacing NaN values with a new label called 'Missing'
df_test[features_with_nan] = df_test[features_with_nan].fillna('Missing')
df_test[features_with_nan].isnull().sum()
# Out:
# MSZoning        0
# Alley           0
# Utilities       0
# Exterior1st     0
# Exterior2nd     0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# KitchenQual     0
# Functional      0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# SaleType        0
# dtype: int64

# %%
# Printing updated dataframe
df_test.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave  Missing      Reg
# 1462          20       RL         81.0    14267   Pave  Missing      IR1
# 1463          60       RL         74.0    13830   Pave  Missing      IR1
# 1464          60       RL         78.0     9978   Pave  Missing      IR1
# 1465         120       RL         43.0     5005   Pave  Missing      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1461         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1462         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 1463         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1464         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1465         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1461       Norm     1Fam     1Story            5            6       1961
# 1462       Norm     1Fam     1Story            6            6       1958
# 1463       Norm     1Fam     2Story            5            5       1997
# 1464       Norm     1Fam     2Story            6            6       1998
# 1465       Norm   TwnhsE     1Story            8            5       1992
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1461          1961     Gable  CompShg     VinylSd     VinylSd       None
# 1462          1958       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 1463          1998     Gable  CompShg     VinylSd     VinylSd       None
# 1464          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1465          1992     Gable  CompShg     HdBoard     HdBoard       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 1461         0.0        TA        TA     CBlock       TA       TA
# 1462       108.0        TA        TA     CBlock       TA       TA
# 1463         0.0        TA        TA      PConc       Gd       TA
# 1464        20.0        TA        TA      PConc       TA       TA
# 1465         0.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 1461           No          Rec       468.0          LwQ       144.0
# 1462           No          ALQ       923.0          Unf         0.0
# 1463           No          GLQ       791.0          Unf         0.0
# 1464           No          GLQ       602.0          Unf         0.0
# 1465           No          ALQ       263.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 1461      270.0        882.0    GasA        TA          Y      SBrkr
# 1462      406.0       1329.0    GasA        TA          Y      SBrkr
# 1463      137.0        928.0    GasA        Gd          Y      SBrkr
# 1464      324.0        926.0    GasA        Ex          Y      SBrkr
# 1465     1017.0       1280.0    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1461       896         0             0        896           0.0           0.0
# 1462      1329         0             0       1329           0.0           0.0
# 1463       928       701             0       1629           0.0           0.0
# 1464       926       678             0       1604           0.0           0.0
# 1465      1280         0             0       1280           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 1461         1         0             2             1          TA
# 1462         1         1             3             1          Gd
# 1463         2         1             3             1          TA
# 1464         2         1             3             1          Gd
# 1465         2         0             2             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# Id
# 1461             5        Typ           0     Missing     Attchd       1961.0
# 1462             6        Typ           0     Missing     Attchd       1958.0
# 1463             6        Typ           1          TA     Attchd       1997.0
# 1464             7        Typ           1          Gd     Attchd       1998.0
# 1465             5        Typ           0     Missing     Attchd       1992.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# Id
# 1461          Unf         1.0       730.0         TA         TA          Y
# 1462          Unf         1.0       312.0         TA         TA          Y
# 1463          Fin         2.0       482.0         TA         TA          Y
# 1464          Fin         2.0       470.0         TA         TA          Y
# 1465          RFn         2.0       506.0         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 1461         140            0              0          0          120
# 1462         393           36              0          0            0
# 1463         212           34              0          0            0
# 1464         360           36              0          0            0
# 1465           0           82              0          0          144
#
#       PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  YrSold  \
# Id
# 1461         0  Missing    MnPrv     Missing        0       6    2010
# 1462         0  Missing  Missing        Gar2    12500       6    2010
# 1463         0  Missing    MnPrv     Missing        0       3    2010
# 1464         0  Missing  Missing     Missing        0       6    2010
# 1465         0  Missing  Missing     Missing        0       1    2010
#
#      SaleType SaleCondition  LotFrontage_NaN  GarageYrBlt_NaN
# Id
# 1461       WD        Normal                0                0
# 1462       WD        Normal                0                0
# 1463       WD        Normal                0                0
# 1464       WD        Normal                0                0
# 1465       WD        Normal                0                0

# %% [markdown]
# #### Handling Missing/NaN Values in Temporal Features

# %%
# Extracting features with years 
year_features = [feature for feature in df_test.columns if ('Yr' in feature or 'Year' in feature) and 'NaN' not in feature]
year_features
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
# Converting year into age for first 3 features (in year_features) by taking difference between 'YrSold' and the feature
for feature in year_features[:-1]:
    df_test[feature] = df_test['YrSold'] - df_test[feature]
df_test.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave  Missing      Reg
# 1462          20       RL         81.0    14267   Pave  Missing      IR1
# 1463          60       RL         74.0    13830   Pave  Missing      IR1
# 1464          60       RL         78.0     9978   Pave  Missing      IR1
# 1465         120       RL         43.0     5005   Pave  Missing      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1461         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1462         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 1463         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1464         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1465         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1461       Norm     1Fam     1Story            5            6         49
# 1462       Norm     1Fam     1Story            6            6         52
# 1463       Norm     1Fam     2Story            5            5         13
# 1464       Norm     1Fam     2Story            6            6         12
# 1465       Norm   TwnhsE     1Story            8            5         18
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1461            49     Gable  CompShg     VinylSd     VinylSd       None
# 1462            52       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 1463            12     Gable  CompShg     VinylSd     VinylSd       None
# 1464            12     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1465            18     Gable  CompShg     HdBoard     HdBoard       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 1461         0.0        TA        TA     CBlock       TA       TA
# 1462       108.0        TA        TA     CBlock       TA       TA
# 1463         0.0        TA        TA      PConc       Gd       TA
# 1464        20.0        TA        TA      PConc       TA       TA
# 1465         0.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 1461           No          Rec       468.0          LwQ       144.0
# 1462           No          ALQ       923.0          Unf         0.0
# 1463           No          GLQ       791.0          Unf         0.0
# 1464           No          GLQ       602.0          Unf         0.0
# 1465           No          ALQ       263.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 1461      270.0        882.0    GasA        TA          Y      SBrkr
# 1462      406.0       1329.0    GasA        TA          Y      SBrkr
# 1463      137.0        928.0    GasA        Gd          Y      SBrkr
# 1464      324.0        926.0    GasA        Ex          Y      SBrkr
# 1465     1017.0       1280.0    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1461       896         0             0        896           0.0           0.0
# 1462      1329         0             0       1329           0.0           0.0
# 1463       928       701             0       1629           0.0           0.0
# 1464       926       678             0       1604           0.0           0.0
# 1465      1280         0             0       1280           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 1461         1         0             2             1          TA
# 1462         1         1             3             1          Gd
# 1463         2         1             3             1          TA
# 1464         2         1             3             1          Gd
# 1465         2         0             2             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# Id
# 1461             5        Typ           0     Missing     Attchd         49.0
# 1462             6        Typ           0     Missing     Attchd         52.0
# 1463             6        Typ           1          TA     Attchd         13.0
# 1464             7        Typ           1          Gd     Attchd         12.0
# 1465             5        Typ           0     Missing     Attchd         18.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# Id
# 1461          Unf         1.0       730.0         TA         TA          Y
# 1462          Unf         1.0       312.0         TA         TA          Y
# 1463          Fin         2.0       482.0         TA         TA          Y
# 1464          Fin         2.0       470.0         TA         TA          Y
# 1465          RFn         2.0       506.0         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 1461         140            0              0          0          120
# 1462         393           36              0          0            0
# 1463         212           34              0          0            0
# 1464         360           36              0          0            0
# 1465           0           82              0          0          144
#
#       PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  YrSold  \
# Id
# 1461         0  Missing    MnPrv     Missing        0       6    2010
# 1462         0  Missing  Missing        Gar2    12500       6    2010
# 1463         0  Missing    MnPrv     Missing        0       3    2010
# 1464         0  Missing  Missing     Missing        0       6    2010
# 1465         0  Missing  Missing     Missing        0       1    2010
#
#      SaleType SaleCondition  LotFrontage_NaN  GarageYrBlt_NaN
# Id
# 1461       WD        Normal                0                0
# 1462       WD        Normal                0                0
# 1463       WD        Normal                0                0
# 1464       WD        Normal                0                0
# 1465       WD        Normal                0                0

# %%
# Printing specific columns from dataframe after updation
df_test[year_features].head()
# Out:
#       YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# Id
# 1461         49            49         49.0    2010
# 1462         52            52         52.0    2010
# 1463         13            12         13.0    2010
# 1464         12            12         12.0    2010
# 1465         18            18         18.0    2010

# %% [markdown]
# #### Handling Skewed Continous Numerical Features

# %%
# Extracting continous numerical features 
continous_numerical_features = [feature for feature in df_test.columns 
                                if df_test[feature].dtype != 'O' and feature not in year_features and df_test[feature].nunique() >= 25]

for feature in continous_numerical_features:
    if 0 not in df_test[feature].unique():
        df_test[feature] = np.log(df_test[feature])
        
df_test.head()
# Out:
#       MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# Id
# 1461          20       RH     4.382027  9.360655   Pave  Missing      Reg
# 1462          20       RL     4.394449  9.565704   Pave  Missing      IR1
# 1463          60       RL     4.304065  9.534595   Pave  Missing      IR1
# 1464          60       RL     4.356709  9.208138   Pave  Missing      IR1
# 1465         120       RL     3.761200  8.518193   Pave  Missing      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1461         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1462         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 1463         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1464         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1465         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1461       Norm     1Fam     1Story            5            6         49
# 1462       Norm     1Fam     1Story            6            6         52
# 1463       Norm     1Fam     2Story            5            5         13
# 1464       Norm     1Fam     2Story            6            6         12
# 1465       Norm   TwnhsE     1Story            8            5         18
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1461            49     Gable  CompShg     VinylSd     VinylSd       None
# 1462            52       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 1463            12     Gable  CompShg     VinylSd     VinylSd       None
# 1464            12     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1465            18     Gable  CompShg     HdBoard     HdBoard       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 1461         0.0        TA        TA     CBlock       TA       TA
# 1462       108.0        TA        TA     CBlock       TA       TA
# 1463         0.0        TA        TA      PConc       Gd       TA
# 1464        20.0        TA        TA      PConc       TA       TA
# 1465         0.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 1461           No          Rec       468.0          LwQ       144.0
# 1462           No          ALQ       923.0          Unf         0.0
# 1463           No          GLQ       791.0          Unf         0.0
# 1464           No          GLQ       602.0          Unf         0.0
# 1465           No          ALQ       263.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 1461      270.0        882.0    GasA        TA          Y      SBrkr
# 1462      406.0       1329.0    GasA        TA          Y      SBrkr
# 1463      137.0        928.0    GasA        Gd          Y      SBrkr
# 1464      324.0        926.0    GasA        Ex          Y      SBrkr
# 1465     1017.0       1280.0    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1461  6.797940         0             0   6.797940           0.0           0.0
# 1462  7.192182         0             0   7.192182           0.0           0.0
# 1463  6.833032       701             0   7.395722           0.0           0.0
# 1464  6.830874       678             0   7.380256           0.0           0.0
# 1465  7.154615         0             0   7.154615           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 1461         1         0             2             1          TA
# 1462         1         1             3             1          Gd
# 1463         2         1             3             1          TA
# 1464         2         1             3             1          Gd
# 1465         2         0             2             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# Id
# 1461             5        Typ           0     Missing     Attchd         49.0
# 1462             6        Typ           0     Missing     Attchd         52.0
# 1463             6        Typ           1          TA     Attchd         13.0
# 1464             7        Typ           1          Gd     Attchd         12.0
# 1465             5        Typ           0     Missing     Attchd         18.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# Id
# 1461          Unf         1.0       730.0         TA         TA          Y
# 1462          Unf         1.0       312.0         TA         TA          Y
# 1463          Fin         2.0       482.0         TA         TA          Y
# 1464          Fin         2.0       470.0         TA         TA          Y
# 1465          RFn         2.0       506.0         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 1461         140            0              0          0          120
# 1462         393           36              0          0            0
# 1463         212           34              0          0            0
# 1464         360           36              0          0            0
# 1465           0           82              0          0          144
#
#       PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  YrSold  \
# Id
# 1461         0  Missing    MnPrv     Missing        0       6    2010
# 1462         0  Missing  Missing        Gar2    12500       6    2010
# 1463         0  Missing    MnPrv     Missing        0       3    2010
# 1464         0  Missing  Missing     Missing        0       6    2010
# 1465         0  Missing  Missing     Missing        0       1    2010
#
#      SaleType SaleCondition  LotFrontage_NaN  GarageYrBlt_NaN
# Id
# 1461       WD        Normal                0                0
# 1462       WD        Normal                0                0
# 1463       WD        Normal                0                0
# 1464       WD        Normal                0                0
# 1465       WD        Normal                0                0

# %% [markdown]
# #### Handling Rare Categories in Categorical Features

# %%
# Extracting categorical variables
# No need to account for year_features as they are a number now
categorical_features = [feature for feature in df_test.columns if df_test[feature].dtype == 'O'] 
print(categorical_features)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
# Replacing rare categories in all categorical features by label 'Rare_Var'
for feature in categorical_features:
    temp = df_test.groupby(feature)[feature].count()/len(df_test)
    indices = temp[temp > 0.01].index
    df_test[feature] = np.where(df_test[feature].isin(indices), df_test[feature], 'Rare_Var')

df_test.head(10)
# Out:
#       MSSubClass  MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# Id
# 1461          20  Rare_Var     4.382027  9.360655   Pave  Missing      Reg
# 1462          20        RL     4.394449  9.565704   Pave  Missing      IR1
# 1463          60        RL     4.304065  9.534595   Pave  Missing      IR1
# 1464          60        RL     4.356709  9.208138   Pave  Missing      IR1
# 1465         120        RL     3.761200  8.518193   Pave  Missing      IR1
# 1466          60        RL     4.317488  9.210340   Pave  Missing      IR1
# 1467          20        RL     4.204693  8.984694   Pave  Missing      IR1
# 1468          60        RL     4.143135  9.036225   Pave  Missing      IR1
# 1469          20        RL     4.442651  9.227787   Pave  Missing      Reg
# 1470          20        RL     4.248495  9.035987   Pave  Missing      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1461         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1462         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 1463         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1464         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1465         HLS    AllPub    Inside       Gtl      StoneBr       Norm
# 1466         Lvl    AllPub    Corner       Gtl      Gilbert       Norm
# 1467         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1468         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1469         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1470         Lvl    AllPub    Corner       Gtl        NAmes       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1461       Norm     1Fam     1Story            5            6         49
# 1462       Norm     1Fam     1Story            6            6         52
# 1463       Norm     1Fam     2Story            5            5         13
# 1464       Norm     1Fam     2Story            6            6         12
# 1465       Norm   TwnhsE     1Story            8            5         18
# 1466       Norm     1Fam     2Story            6            5         17
# 1467       Norm     1Fam     1Story            6            7         18
# 1468       Norm     1Fam     2Story            6            5         12
# 1469       Norm     1Fam     1Story            7            5         20
# 1470       Norm     1Fam     1Story            4            5         40
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1461            49     Gable  CompShg     VinylSd     VinylSd       None
# 1462            52       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 1463            12     Gable  CompShg     VinylSd     VinylSd       None
# 1464            12     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1465            18     Gable  CompShg     HdBoard     HdBoard       None
# 1466            16     Gable  CompShg     HdBoard     HdBoard       None
# 1467             3     Gable  CompShg     HdBoard     HdBoard       None
# 1468            12     Gable  CompShg     VinylSd     VinylSd       None
# 1469            20     Gable  CompShg     HdBoard     HdBoard       None
# 1470            40     Gable  CompShg     Plywood     Plywood       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 1461         0.0        TA        TA     CBlock       TA       TA
# 1462       108.0        TA        TA     CBlock       TA       TA
# 1463         0.0        TA        TA      PConc       Gd       TA
# 1464        20.0        TA        TA      PConc       TA       TA
# 1465         0.0        Gd        TA      PConc       Gd       TA
# 1466         0.0        TA        TA      PConc       Gd       TA
# 1467         0.0        TA        Gd      PConc       Gd       TA
# 1468         0.0        TA        TA      PConc       Gd       TA
# 1469         0.0        TA        TA      PConc       Gd       TA
# 1470         0.0        TA        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 1461           No          Rec       468.0          LwQ       144.0
# 1462           No          ALQ       923.0          Unf         0.0
# 1463           No          GLQ       791.0          Unf         0.0
# 1464           No          GLQ       602.0          Unf         0.0
# 1465           No          ALQ       263.0          Unf         0.0
# 1466           No          Unf         0.0          Unf         0.0
# 1467           No          ALQ       935.0          Unf         0.0
# 1468           No          Unf         0.0          Unf         0.0
# 1469           Gd          GLQ       637.0          Unf         0.0
# 1470           No          ALQ       804.0          Rec        78.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 1461      270.0        882.0    GasA        TA          Y      SBrkr
# 1462      406.0       1329.0    GasA        TA          Y      SBrkr
# 1463      137.0        928.0    GasA        Gd          Y      SBrkr
# 1464      324.0        926.0    GasA        Ex          Y      SBrkr
# 1465     1017.0       1280.0    GasA        Ex          Y      SBrkr
# 1466      763.0        763.0    GasA        Gd          Y      SBrkr
# 1467      233.0       1168.0    GasA        Ex          Y      SBrkr
# 1468      789.0        789.0    GasA        Gd          Y      SBrkr
# 1469      663.0       1300.0    GasA        Gd          Y      SBrkr
# 1470        0.0        882.0    GasA        TA          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1461  6.797940         0             0   6.797940           0.0           0.0
# 1462  7.192182         0             0   7.192182           0.0           0.0
# 1463  6.833032       701             0   7.395722           0.0           0.0
# 1464  6.830874       678             0   7.380256           0.0           0.0
# 1465  7.154615         0             0   7.154615           0.0           0.0
# 1466  6.637258       892             0   7.411556           0.0           0.0
# 1467  7.079184         0             0   7.079184           1.0           0.0
# 1468  6.670766       676             0   7.289611           0.0           0.0
# 1469  7.201171         0             0   7.201171           1.0           0.0
# 1470  6.782192         0             0   6.782192           1.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 1461         1         0             2             1          TA
# 1462         1         1             3             1          Gd
# 1463         2         1             3             1          TA
# 1464         2         1             3             1          Gd
# 1465         2         0             2             1          Gd
# 1466         2         1             3             1          TA
# 1467         2         0             3             1          TA
# 1468         2         1             3             1          TA
# 1469         1         1             2             1          Gd
# 1470         1         0             2             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# Id
# 1461             5        Typ           0     Missing     Attchd         49.0
# 1462             6        Typ           0     Missing     Attchd         52.0
# 1463             6        Typ           1          TA     Attchd         13.0
# 1464             7        Typ           1          Gd     Attchd         12.0
# 1465             5        Typ           0     Missing     Attchd         18.0
# 1466             7        Typ           1          TA     Attchd         17.0
# 1467             6        Typ           0     Missing     Attchd         18.0
# 1468             7        Typ           1          Gd     Attchd         12.0
# 1469             5        Typ           1          Po     Attchd         20.0
# 1470             4        Typ           0     Missing     Attchd         40.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# Id
# 1461          Unf         1.0       730.0         TA         TA          Y
# 1462          Unf         1.0       312.0         TA         TA          Y
# 1463          Fin         2.0       482.0         TA         TA          Y
# 1464          Fin         2.0       470.0         TA         TA          Y
# 1465          RFn         2.0       506.0         TA         TA          Y
# 1466          Fin         2.0       440.0         TA         TA          Y
# 1467          Fin         2.0       420.0         TA         TA          Y
# 1468          Fin         2.0       393.0         TA         TA          Y
# 1469          Unf         2.0       506.0         TA         TA          Y
# 1470          Fin         2.0       525.0         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 1461         140            0              0          0          120
# 1462         393           36              0          0            0
# 1463         212           34              0          0            0
# 1464         360           36              0          0            0
# 1465           0           82              0          0          144
# 1466         157           84              0          0            0
# 1467         483           21              0          0            0
# 1468           0           75              0          0            0
# 1469         192            0              0          0            0
# 1470         240            0              0          0            0
#
#       PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  YrSold  \
# Id
# 1461         0  Missing    MnPrv     Missing        0       6    2010
# 1462         0  Missing  Missing    Rare_Var    12500       6    2010
# 1463         0  Missing    MnPrv     Missing        0       3    2010
# 1464         0  Missing  Missing     Missing        0       6    2010
# 1465         0  Missing  Missing     Missing        0       1    2010
# 1466         0  Missing  Missing     Missing        0       4    2010
# 1467         0  Missing    GdPrv        Shed      500       3    2010
# 1468         0  Missing  Missing     Missing        0       5    2010
# 1469         0  Missing  Missing     Missing        0       2    2010
# 1470         0  Missing    MnPrv     Missing        0       4    2010
#
#      SaleType SaleCondition  LotFrontage_NaN  GarageYrBlt_NaN
# Id
# 1461       WD        Normal                0                0
# 1462       WD        Normal                0                0
# 1463       WD        Normal                0                0
# 1464       WD        Normal                0                0
# 1465       WD        Normal                0                0
# 1466       WD        Normal                0                0
# 1467       WD        Normal                1                0
# 1468       WD        Normal                0                0
# 1469       WD        Normal                0                0
# 1470       WD        Normal                0                0

# %% [markdown]
# #### Applying Label Encodig

# %%
# Applying label encoder on each categorical feature to convert it from string to number
for feature in categorical_features:
    encoder = LabelEncoder()
    df_test[feature] = encoder.fit_transform(df_test[feature])
df_test.head()
# Out:
#       MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# Id
# 1461          20         4     4.382027  9.360655       0      1         3
# 1462          20         2     4.394449  9.565704       0      1         0
# 1463          60         2     4.304065  9.534595       0      1         0
# 1464          60         2     4.356709  9.208138       0      1         0
# 1465         120         2     3.761200  8.518193       0      1         0
#
#       LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# Id
# 1461            3          0          3          0             9           1
# 1462            3          0          0          0             9           2
# 1463            3          0          3          0             5           2
# 1464            3          0          3          0             5           2
# 1465            1          0          3          0            19           2
#
#       Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1461           0         0           1            5            6         49
# 1462           0         0           1            6            6         52
# 1463           0         0           2            5            5         13
# 1464           0         0           2            6            6         12
# 1465           0         4           1            8            5         18
#
#       YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  \
# Id
# 1461            49          0         0            8            9           2
# 1462            52          1         0            9           10           0
# 1463            12          0         0            8            9           2
# 1464            12          0         0            8            9           0
# 1465            18          0         0            3            4           2
#
#       MasVnrArea  ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  \
# Id
# 1461         0.0          3          3           1         4         4
# 1462       108.0          3          3           1         4         4
# 1463         0.0          3          3           2         2         4
# 1464        20.0          3          3           2         4         4
# 1465         0.0          2          3           2         2         4
#
#       BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  BsmtFinSF2  \
# Id
# 1461             4             5       468.0             3       144.0
# 1462             4             0       923.0             6         0.0
# 1463             4             2       791.0             6         0.0
# 1464             4             2       602.0             6         0.0
# 1465             4             0       263.0             6         0.0
#
#       BsmtUnfSF  TotalBsmtSF  Heating  HeatingQC  CentralAir  Electrical  \
# Id
# 1461      270.0        882.0        0          4           1           3
# 1462      406.0       1329.0        0          4           1           3
# 1463      137.0        928.0        0          2           1           3
# 1464      324.0        926.0        0          0           1           3
# 1465     1017.0       1280.0        0          0           1           3
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1461  6.797940         0             0   6.797940           0.0           0.0
# 1462  7.192182         0             0   7.192182           0.0           0.0
# 1463  6.833032       701             0   7.395722           0.0           0.0
# 1464  6.830874       678             0   7.380256           0.0           0.0
# 1465  7.154615         0             0   7.154615           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  KitchenQual  \
# Id
# 1461         1         0             2             1            4
# 1462         1         1             3             1            2
# 1463         2         1             3             1            4
# 1464         2         1             3             1            2
# 1465         2         0             2             1            2
#
#       TotRmsAbvGrd  Functional  Fireplaces  FireplaceQu  GarageType  \
# Id
# 1461             5           4           0            3           1
# 1462             6           4           0            3           1
# 1463             6           4           1            5           1
# 1464             7           4           1            2           1
# 1465             5           4           0            3           1
#
#       GarageYrBlt  GarageFinish  GarageCars  GarageArea  GarageQual  \
# Id
# 1461         49.0             3         1.0       730.0           3
# 1462         52.0             3         1.0       312.0           3
# 1463         13.0             0         2.0       482.0           3
# 1464         12.0             0         2.0       470.0           3
# 1465         18.0             2         2.0       506.0           3
#
#       GarageCond  PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# Id
# 1461           3           2         140            0              0
# 1462           3           2         393           36              0
# 1463           3           2         212           34              0
# 1464           3           2         360           36              0
# 1465           3           2           0           82              0
#
#       3SsnPorch  ScreenPorch  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# Id
# 1461          0          120         0       0      3            0        0
# 1462          0            0         0       0      2            1    12500
# 1463          0            0         0       0      3            0        0
# 1464          0            0         0       0      2            0        0
# 1465          0          144         0       0      2            0        0
#
#       MoSold  YrSold  SaleType  SaleCondition  LotFrontage_NaN  \
# Id
# 1461       6    2010         4              2                0
# 1462       6    2010         4              2                0
# 1463       3    2010         4              2                0
# 1464       6    2010         4              2                0
# 1465       1    2010         4              2                0
#
#       GarageYrBlt_NaN
# Id
# 1461                0
# 1462                0
# 1463                0
# 1464                0
# 1465                0

# %% [markdown]
# #### Applying Feature Scaling

# %%
# Scaling features using MinMaxScaler
df_test = pd.DataFrame(scaler.transform(df_test), columns=df_test.columns, index=df_test.index)
df_test.head()
# Out:
#       MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# Id
# 1461    0.000000       1.0     0.495064  0.428726     0.0    0.5       1.0
# 1462    0.000000       0.5     0.499662  0.468857     0.0    0.5       0.0
# 1463    0.235294       0.5     0.466207  0.462769     0.0    0.5       0.0
# 1464    0.235294       0.5     0.485693  0.398875     0.0    0.5       0.0
# 1465    0.588235       0.5     0.265271  0.263841     0.0    0.5       0.0
#
#       LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# Id
# 1461     1.000000        0.0       0.75        0.0      0.409091         0.2
# 1462     1.000000        0.0       0.00        0.0      0.409091         0.4
# 1463     1.000000        0.0       0.75        0.0      0.227273         0.4
# 1464     1.000000        0.0       0.75        0.0      0.227273         0.4
# 1465     0.333333        0.0       0.75        0.0      0.863636         0.4
#
#       Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1461         0.0       0.0         0.2     0.444444        0.625   0.360294
# 1462         0.0       0.0         0.2     0.555556        0.625   0.382353
# 1463         0.0       0.0         0.4     0.444444        0.500   0.095588
# 1464         0.0       0.0         0.4     0.555556        0.625   0.088235
# 1465         0.0       1.0         0.2     0.777778        0.500   0.132353
#
#       YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  \
# Id
# 1461      0.819672        0.0       0.0          0.8          0.9         0.5
# 1462      0.868852        0.5       0.0          0.9          1.0         0.0
# 1463      0.213115        0.0       0.0          0.8          0.9         0.5
# 1464      0.213115        0.0       0.0          0.8          0.9         0.0
# 1465      0.311475        0.0       0.0          0.3          0.4         0.5
#
#       MasVnrArea  ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  \
# Id
# 1461      0.0000   1.000000        1.0        0.25       1.0       1.0
# 1462      0.0675   1.000000        1.0        0.25       1.0       1.0
# 1463      0.0000   1.000000        1.0        0.50       0.5       1.0
# 1464      0.0125   1.000000        1.0        0.50       1.0       1.0
# 1465      0.0000   0.666667        1.0        0.50       0.5       1.0
#
#       BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  BsmtFinSF2  \
# Id
# 1461           1.0      0.833333    0.082920           0.5    0.097693
# 1462           1.0      0.000000    0.163536           1.0    0.000000
# 1463           1.0      0.333333    0.140149           1.0    0.000000
# 1464           1.0      0.333333    0.106662           1.0    0.000000
# 1465           1.0      0.000000    0.046598           1.0    0.000000
#
#       BsmtUnfSF  TotalBsmtSF  Heating  HeatingQC  CentralAir  Electrical  \
# Id
# 1461   0.115582     0.144354      0.0        1.0         1.0         1.0
# 1462   0.173801     0.217512      0.0        1.0         1.0         1.0
# 1463   0.058647     0.151882      0.0        0.5         1.0         1.0
# 1464   0.138699     0.151555      0.0        0.0         1.0         1.0
# 1465   0.435360     0.209493      0.0        0.0         1.0         1.0
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1461  0.373438  0.000000           0.0   0.349081           0.0           0.0
# 1462  0.522632  0.000000           0.0   0.488544           0.0           0.0
# 1463  0.386718  0.339467           0.0   0.560546           0.0           0.0
# 1464  0.385901  0.328329           0.0   0.555075           0.0           0.0
# 1465  0.508416  0.000000           0.0   0.475254           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  KitchenQual  \
# Id
# 1461  0.333333       0.0         0.250      0.333333     1.333333
# 1462  0.333333       0.5         0.375      0.333333     0.666667
# 1463  0.666667       0.5         0.375      0.333333     1.333333
# 1464  0.666667       0.5         0.375      0.333333     0.666667
# 1465  0.666667       0.0         0.250      0.333333     0.666667
#
#       TotRmsAbvGrd  Functional  Fireplaces  FireplaceQu  GarageType  \
# Id
# 1461      0.250000         1.0    0.000000          0.6         0.2
# 1462      0.333333         1.0    0.000000          0.6         0.2
# 1463      0.333333         1.0    0.333333          1.0         0.2
# 1464      0.416667         1.0    0.333333          0.4         0.2
# 1465      0.250000         1.0    0.000000          0.6         0.2
#
#       GarageYrBlt  GarageFinish  GarageCars  GarageArea  GarageQual  \
# Id
# 1461     0.457944      1.000000        0.25    0.514810         1.0
# 1462     0.485981      1.000000        0.25    0.220028         1.0
# 1463     0.121495      0.000000        0.50    0.339915         1.0
# 1464     0.112150      0.000000        0.50    0.331453         1.0
# 1465     0.168224      0.666667        0.50    0.356841         1.0
#
#       GarageCond  PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# Id
# 1461         1.0         1.0    0.163361     0.000000            0.0
# 1462         1.0         1.0    0.458576     0.065814            0.0
# 1463         1.0         1.0    0.247375     0.062157            0.0
# 1464         1.0         1.0    0.420070     0.065814            0.0
# 1465         1.0         1.0    0.000000     0.149909            0.0
#
#       3SsnPorch  ScreenPorch  PoolArea  PoolQC  Fence  MiscFeature   MiscVal  \
# Id
# 1461        0.0         0.25       0.0     0.0   0.75          0.0  0.000000
# 1462        0.0         0.00       0.0     0.0   0.50          0.5  0.806452
# 1463        0.0         0.00       0.0     0.0   0.75          0.0  0.000000
# 1464        0.0         0.00       0.0     0.0   0.50          0.0  0.000000
# 1465        0.0         0.30       0.0     0.0   0.50          0.0  0.000000
#
#         MoSold  YrSold  SaleType  SaleCondition  LotFrontage_NaN  \
# Id
# 1461  0.454545     1.0  1.333333            0.5              0.0
# 1462  0.454545     1.0  1.333333            0.5              0.0
# 1463  0.181818     1.0  1.333333            0.5              0.0
# 1464  0.454545     1.0  1.333333            0.5              0.0
# 1465  0.000000     1.0  1.333333            0.5              0.0
#
#       GarageYrBlt_NaN
# Id
# 1461              0.0
# 1462              0.0
# 1463              0.0
# 1464              0.0
# 1465              0.0

# %% [markdown]
# #### Exporting Processed Test Data

# %%
# Exporting Test Data to CSV file
df_test.to_csv('test_preprocessed.csv')
